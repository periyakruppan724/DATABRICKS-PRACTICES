# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("Spark DataFrames").getOrCreate()
data = [
    (1, "Ravi", 25000),
    (2, "Ramu", 30000),
    (3, "Kumar", 35000)
]

columns = ["id", "name", "salary"]

df = spark.createDataFrame(data, columns)

df.show()
# Out:
# +---+-----+------+
# | id| name|salary|
# +---+-----+------+
# |  1| Ravi| 25000|
# |  2| Ramu| 30000|
# |  3|Kumar| 35000|
# +---+-----+------+

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>salary</th></tr></thead><tbody><tr><td>1</td><td>Ravi</td><td>25000</td></tr><tr><td>2</td><td>Ramu</td><td>30000</td></tr><tr><td>3</td><td>Kumar</td><td>35000</td></tr></tbody></table></div>

# %%
df.printSchema()
# Out:
# root
#  |-- id: long (nullable = true)
#  |-- name: string (nullable = true)
#  |-- salary: long (nullable = true)

# %%
df.select("name", "salary").show()
# Out:
# +-----+------+
# | name|salary|
# +-----+------+
# | Ravi| 25000|
# | Ramu| 30000|
# |Kumar| 35000|
# +-----+------+

# %%
df.filter(df.salary > 25000).show()
# Out:
# +---+-----+------+
# | id| name|salary|
# +---+-----+------+
# |  2| Ramu| 30000|
# |  3|Kumar| 35000|
# +---+-----+------+

# %%
from pyspark.sql.functions import col

df_new = df.withColumn("bonus", col("salary") * 0.10)

df_new.show()
# Out:
# +---+-----+------+------+
# | id| name|salary| bonus|
# +---+-----+------+------+
# |  1| Ravi| 25000|2500.0|
# |  2| Ramu| 30000|3000.0|
# |  3|Kumar| 35000|3500.0|
# +---+-----+------+------+

# %%
df = df.withColumnRenamed("salary", "emp_salary")

df.show()
# Out:
# +---+-----+----------+
# | id| name|emp_salary|
# +---+-----+----------+
# |  1| Ravi|     25000|
# |  2| Ramu|     30000|
# |  3|Kumar|     35000|
# +---+-----+----------+

# %%
df.drop("emp_salary").show()
# Out:
# +---+-----+
# | id| name|
# +---+-----+
# |  1| Ravi|
# |  2| Ramu|
# |  3|Kumar|
# +---+-----+

# %%
df.orderBy("salary").show()
# Out:
# +---+-----+----------+
# | id| name|emp_salary|
# +---+-----+----------+
# |  1| Ravi|     25000|
# |  2| Ramu|     30000|
# |  3|Kumar|     35000|
# +---+-----+----------+

# %%
df.count()
# Out:
# 3
